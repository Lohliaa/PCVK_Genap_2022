# %% [markdown]
# <a href="https://colab.research.google.com/github/Lohliaa/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM**
# 1.	Setelah dipastikan bahwa google Colab terhubung dengan Github Anda, lanjutkan dengan memilih repository yang telah digunakan pada praktikum minggu lalu, rename file menjadi “Week2.ipynb”.

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang sudah ada. Contohnya pada kode program di bawah file image dengan nama kitten01.jpg akan dibuka untuk diproses lebih lanjut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread("/content/drive/MyDrive/PCVK/Week2/kitten01.jpg")
plt.imshow(img)

# %% [markdown]
# 2.	OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)   # konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# 3.	Menampilkan citra Grayscale, melakukan resizing, melakukan flipping, menyimpan citra hasil

# %%
img_gray = cv.imread("/content/drive/MyDrive/PCVK/Week2/kitten01.jpg", cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk menampilkan colormap dengan warna ‘gary’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

# simpan file image
# cv.imwrite("/content/drive/MyDrive/PCVK/Week2/kitten01.jpg", img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10, 10))    # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 4.	Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
# perhatikan koordinat titik-titik pt1 dan pt2
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut

# %%
cv.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10, 500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi Numpy array dengan tipe data int32

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1, 1, 2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **PERTANYAAN**
#
# 1.	Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# Jawab:
# Jika menggunakan matplotlib, gambar akan ditampilkan dengan ukuran di samping dan bawah. Dengan ukuran tersebut akan lebih memudahkan dalam menentukan koordinat gambar
#
# 2.	Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int 16 dan int 32?
#
# Jawab:
# Perbedaan tipe data int16 dan int32 terletak pada jumlah bit dalam gambar.
#
# 3.	Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
#
# Jawab :
# Kegunaan “google.colab.patches import cv2_imshow” untuk memanggil fungsi google colab untuk perbaikan c2_imshow yang mana imshow berfungsi untuk menampilkan gambar
#
# 4.	Apakah kegunaan skimage import io pada potongan kode soal nomor 3
#
# Jawab:
# Kegunaan skimage yaitu untuk melakukan visualisasi data secara 2D maupun 3D dan menghasilkan suatu gambar yang berkualitas bahkan dapat disimpan dengan format gambar seperti JPEG, JPG dan PNG, sedangkan kegunaan io untuk memproses dan menampilkan hasil output

# %% [markdown]
# **TUGAS**
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut:
# 1.	Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
#
# Jawab:
# Dengan menggunakan figsize, ukuran pixel image tidak ikut berubah
#
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
#
# Jawab:

# %%
# Red-Blue
plt.imshow(img_gray, cmap='RdBu')

# %%
# Green-Blue
plt.imshow(img_gray, cmap='GnBu')

# %% [markdown]
# 3.	Tampilkan image baris ke 20-115, kolom 25-120
#
# Jawab:

# %%
plt.imshow(img3[20:115, 25:120])

# %% [markdown]
# 4.	Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
#
# Jawab:

# %%
plt.imshow(img_gray[5:30], cmap="Reds")

# %% [markdown]
# 5.  Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

cv.rectangle(img5,pt1=(100,100),pt2=(120,150),color=(0,0,255),thickness=10)
cv.rectangle(img5,pt1=(120,120),pt2=(220,220),color=(0,255,0),thickness=10)
cv.rectangle(img5,pt1=(230,230),pt2=(330,330),color=(255,0,0),thickness=10)
cv.rectangle(img5,pt1=(300,300),pt2=(450,450),color=(255,255,255),thickness=10)
cv.rectangle(img5,pt1=(400,400),pt2=(600,600),color=(0,0,0),thickness=10)


plt.imshow(img5)

# %% [markdown]
# 6.	Tampilkan image dengan posisi terbalik:
#
# Jawab:

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

# simpan file image
# cv.imwrite("/content/drive/MyDrive/PCVK/Week2/kitten01.jpg", img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10, 10))    # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut:
# 7.	Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %%
# load image
my_photo = cv.imread("/content/drive/MyDrive/PCVK/Week2/aku.jpeg")

# convert color channel to RGB
my_photo = cv.cvtColor(my_photo, cv.COLOR_BGR2RGB)

# add rectangle
cv.rectangle(my_photo, pt1=(530, 860), pt2=(1030,330), color=(255, 0, 0), thickness=10)

# add circle
cv.circle(my_photo, center=(780, 600), radius=250, color=(0, 255, 0), thickness=8)

# show image
plt.imshow(my_photo)

# %% [markdown]
# 8.	Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
#
# Jawab:

# %%
# load image
peppers = cv.imread("/content/drive/MyDrive/PCVK/Week2/kitten01.jpg")

# convert color channel to RGB
peppers_rgb = cv.cvtColor(peppers, cv.COLOR_BGR2RGB)

# add rectange
cv.rectangle(peppers_rgb, pt1=(0, 400), pt2=(200, 500), color=(0, 0, 0), thickness=5)

# show image
plt.imshow(peppers_rgb)

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.
#
# Jawab :

# %%
font = cv.FONT_ITALIC
cv.putText(peppers_rgb, text="Kitten.jpg", org=(250, 450), fontFace=font, fontScale=2, color=(0, 0, 0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(peppers_rgb)
